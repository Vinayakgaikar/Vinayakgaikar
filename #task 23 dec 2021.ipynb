# %%
#task

1) you have to write a fun which will take 
   string and return a len of it without using a inbuilt fun len 
2)write a fun which will be able to print an index of all premitive element
  which you will pass
3)write a fun which will take input as a dict and give me out as a list of all 
  the values even in case of 2 level nesting it should work
4) write a fun which will take another fun as an input and return me an output 
5) write a fun which will take multiple list as a input and give me 
   concatination of all the element as an output
6) write a fun which will be able to take a list as an input return as index of 
   each element like inbuilt fun but even if we have repetative element it should 
    return index
7) write a fun which will would return list of all the file name from a directory
8)write a fun which will be able to show your system confuguration
9) write a fun which will be able show date and time
10) write a fun which will be able to read  a image file and show it to you 
11) write a fun which can read video file and play for you 
12)write a fun which will move a file from one dir to another dir
13) write a fun which will be able to shutdown your system
14)write a fun which will be able to access your mail 
15) write a fun by which i can send a mail to anyone
16) write a fun to read a complete pdf file 
17) write a fun to read a word file 
18) write a fun which can help you to filter only word file from a dir 
19) write a fun by which you can print ip address of your system
20) write a fun by which you will be able to append two files

# %%
#1)

n="mynameisvinayak"
def test(n):
    b=0
    for i in n:
        b=b+1
    print(b)
test(n)
# Out:
# 15

# %%
#2
for i in enumerate(n):
        print(i)
# Out:
# (0, 'm')
# (1, 'y')
# (2, 'n')
# (3, 'a')
# (4, 'm')
# (5, 'e')
# (6, 'i')
# (7, 's')
# (8, 'v')
# (9, 'i')
# (10, 'n')
# (11, 'a')
# (12, 'y')
# (13, 'a')
# (14, 'k')

# %%
#3
def test(**kwargs):
    l=[]
    for i in kwargs:
        l.append(kwargs.values())
        break
    return l
    

test(a=10,b=20,c="vinayk",d={"a":5,"h":56})
# Out:
# [dict_values([10, 20, 'vinayk', {'a': 5, 'h': 56}])]

# %%
#4
def test(*args):
    return args
test(1,5,4,"vinayak","ram","rajesh",[4,5,8],[5,8,6],True,{"A":5,"g":56},3.45,4.56)
# Out:
# (1,
#  5,
#  4,
#  'vinayak',
#  'ram',
#  'rajesh',
#  [4, 5, 8],
#  [5, 8, 6],
#  True,
#  {'A': 5, 'g': 56},
#  3.45,
#  4.56)

# %%
#5
def test(*args):
    l=[]
    for i in args:
        if type(i)==list:
            for j in i:
                l.append(j)
    return l
    
    
test([1,5,5,6],[20,45,65,65],["vinayak",45,"india"])
# Out:
# [1, 5, 5, 6, 20, 45, 65, 65, 'vinayak', 45, 'india']

# %%
#6
def test(*args):
    for i in args:
        if type (i)==list:
            for j in enumerate(i):
                print("in list",i,"index is",j)
test([1,5,5,6],[20,45,65,65],["vinayak",45,"india"])
# Out:
# in list [1, 5, 5, 6] index is (0, 1)
# in list [1, 5, 5, 6] index is (1, 5)
# in list [1, 5, 5, 6] index is (2, 5)
# in list [1, 5, 5, 6] index is (3, 6)
# in list [20, 45, 65, 65] index is (0, 20)
# in list [20, 45, 65, 65] index is (1, 45)
# in list [20, 45, 65, 65] index is (2, 65)
# in list [20, 45, 65, 65] index is (3, 65)
# in list ['vinayak', 45, 'india'] index is (0, 'vinayak')
# in list ['vinayak', 45, 'india'] index is (1, 45)
# in list ['vinayak', 45, 'india'] index is (2, 'india')

# %%
#7
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '20 dec if else , for loop class notes 20 dec.ipynb',
#  '21 dec for loops while loop class notes .ipynb',
#  '23 dec 2021 function.ipynb',
#  '8 jan function .ipynb',
#  'for else.ipynb',
#  'Function and files.ipynb',
#  'if for statements.ipynb',
#  'photo.jpg',
#  'TUPLE SET AND DICT.ipynb',
#  'Untitled.ipynb',
#  'vinayak',
#  'vinayak1']

# %%
#8

# import module
import subprocess
 
# traverse the info
Id = subprocess.check_output(['systeminfo']).decode('utf-8').split('\n')
new = []
 
# arrange the string into clear info
for item in Id:
    new.append(str(item.split("\r")[:-1]))
for i in new:
    print(i[2:-2])
# Out:
# Computer network name: DESKTOP-6N5I3OB
# Machine type: AMD64
# Processor type: Intel64 Family 6 Model 126 Stepping 5, GenuineIntel
# Platform type: Windows-10-10.0.19041-SP0
# Operating system: Windows
# Operating system release: 10
# Operating system version: 10.0.19041
#
# Host Name:                 DESKTOP-6N5I3OB
# OS Name:                   Microsoft Windows 10 Home Single Language
# OS Version:                10.0.19043 N/A Build 19043
# OS Manufacturer:           Microsoft Corporation
# OS Configuration:          Standalone Workstation
# OS Build Type:             Multiprocessor Free
# Registered Owner:          Vinayak
# Registered Organization:
# Product ID:                00327-35920-23463-AAOEM
# Original Install Date:     04-10-2021, 14:08:23
# System Boot Time:          08-01-2022, 10:07:31
# System Manufacturer:       Dell Inc.
# System Model:              Inspiron 3501
# System Type:               x64-based PC
# Processor(s):              1 Processor(s) Installed.
# ...

# %%
#9
import datetime
date_time=datetime.datetime.now()
print (date_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2022-01-08 13:40:50

# %%
#10
# importing PIL
from PIL import Image
  
# Read image
Image.open('photo.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x899 at 0x2DB8F2CC850>

# %%
#12
import shutil
a=os.getcwd()
shutil.move("mydir1","vinayak")
# Out:
# 'vinayak\\mydir1'

# %%
#13
import os
os.system("shutdown /s /t 1")
